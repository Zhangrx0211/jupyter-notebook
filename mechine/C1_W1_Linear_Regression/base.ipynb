# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # Jupyter Notebook
# ## 基础操作
#
#     1 shift +回车，运行这行代码，并跳转下面代码快
#       Ctrl + 回车，运行，不会跳转
#       Alt + 回车，运行并在下方新建一个代码快
#     2 x剪切代码快，z恢复代码快
#     3 m切换文本模式，y切换代码模式
#     4 a在上面插入代码快，b在下面插入
#     5 x剪切，c复制，v粘贴，shift+v粘贴到上面，d删除
#
#     6回车：命令模式到编辑模式，ESC相反
#
#     7在命令模型下，按l给当前代码标注行数

# %% [markdown]
# ### 一，Supervised learning(监督学习)
#     学习x(输入)到y（输出）映射的算法
# #### 1,regression(回归)
#     从无限多个可能的数字中预测一个数字
# #### 2,classification(分类)
#     预测类别，类别不一定是数字
# ### 二，Unsupervised learning(无监督学习)常用 自己根据数值特征分析
# #### 1,Clustering(聚类)
# 相似的数据点分组在一起
# #### 2,Anomaly detection(检测异常)
# #### 3，Dimensionality reduction(降维度)
#
# #### Recommender systems(推荐系统)
# #### Reinforcement learning(强化学习)

# %% [markdown]
# ## mechine learning
#     没有明确编程的情况下学习能力的研究领域

# %% [markdown]
# ### 一，Supervised learning(监督学习)
#     学习x(输入)到y（输出）映射的算法
# #### 1,regression(回归)
#     从无限多个可能的数字中预测一个数字
# #### 2,classification(分类)
#     预测类别，类别不一定是数字

# %% [markdown]
# ### 二，Unsupervised learning(无监督学习)常用 自己根据数值特征分析
# #### 1,Clustering(聚类)
# 相似的数据点分组在一起
# #### 2,Anomaly detection(检测异常)
# #### 3，Dimensionality reduction(降维度)
#
# #### Recommender systems(推荐系统)
# #### Reinforcement learning(强化学习)
